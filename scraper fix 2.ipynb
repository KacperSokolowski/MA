# %%
from scraper import *
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
url = 'https://www.otodom.pl/pl/wyniki/wynajem/mieszkanie/mazowieckie/warszawa/warszawa/warszawa?limit=36&daysSinceCreated=7&by=DEFAULT&direction=DESC&viewType=listing&page=2'
df = run_otodom_scraper(first_page_url = url, sleep_length=2)

# %%
df
# Out:
#                                                  title  \
# 0        Nowe Mieszkanie PREMIUM 3 pokoje klimatyzacja
# 1                         Wyjątkowe mieszkanie na Woli
# 2       Przestronne 3-pokojowe mieszkanie BEZPOŚREDNIO
# 3       Mieszkanie 52m2 2 Metro Stadion 2 pokoje klima
# 4       Luksusowy Apartament 53m2, 3 pok. Stare Miasto
# ..                                                 ...
# 387  2 pokoje na kameralnym osiedlu z dużym parkingiem
# 388  Józefosław 3Pokoje 64 M2 Zamknięte Osiedle Par...
# 389                          Mieszkanie 77m Józefosław
# 390    2-pokojowe mieszkanie 38m2 al. Wojska Polskiego
# 391  Kawalerka w nowym budownictwie na ostatnim pię...
#
#                                 rent_price  \
# 0      3 950 zł\n/miesiąc\n+ Czynsz 720 zł
# 1    6 000 zł\n/miesiąc\n+ Czynsz 1 000 zł
# 2    7 700 zł\n/miesiąc\n+ Czynsz 1 640 zł
# 3      5 200 zł\n/miesiąc\n+ Czynsz 600 zł
# 4      5 500 zł\n/miesiąc\n+ Czynsz 700 zł
# ..                                     ...
# 387    2 500 zł\n/miesiąc\n+ Czynsz 722 zł
# 388                     3 000 zł\n/miesiąc
# 389    4 200 zł\n/miesiąc\n+ Czynsz 740 zł
# 390    3 000 zł\n/miesiąc\n+ Czynsz 450 zł
# 391                     2 199 zł\n/miesiąc
#
#                                          area_room_num     floor   ogrzewanie  \
# 0                                       50m²\n3 pokoje       2/2     miejskie
# 1                67m²\n3 pokoje\ntylko dla niepalących       1/8     miejskie
# 2                                    84.61m²\n3 pokoje       6/6     miejskie
# 3            52m²\nWynajmę również studentom\n2 pokoje       5/6     miejskie
# 4                                       53m²\n3 pokoje  parter/3     miejskie
# ..                                                 ...       ...          ...
# 387                                     41m²\n2 pokoje       1/2       gazowe
# 388                                     64m²\n3 pokoje       1/2       gazowe
# 389              77m²\n3 pokoje\ntylko dla niepalących       2/2  elektryczne
# 390  38m²\nWynajmę również studentom\n2 pokoje\ntyl...       1/3         inne
# 391                                      21m²\n1 pokój       4/4     miejskie
#
#       flat_condition available_from    deposit      advertiser_type  \
# 0    do zamieszkania           None   5 000 zł             prywatny
# 1    do zamieszkania           None  10 000 zł             prywatny
# 2    do zamieszkania           None  10 000 zł             prywatny
# 3    do zamieszkania     2024-01-10   5 500 zł             prywatny
# 4    do zamieszkania     2024-11-24       None  biuro nieruchomości
# ..               ...            ...        ...                  ...
# 387  do zamieszkania     2025-01-01   4 000 zł  biuro nieruchomości
# 388  do zamieszkania     2024-12-27       None  biuro nieruchomości
# 389  do zamieszkania           None   4 200 zł             prywatny
# 390  do zamieszkania           None   3 000 zł             prywatny
# 391  do zamieszkania     2025-01-08       None  biuro nieruchomości
#
#                                 additional_information  \
# 0                     balkon\ngaraż/miejsce parkingowe
# 1    balkon\ngaraż/miejsce parkingowe\ntylko dla ni...
# 2              balkon\ntaras\ngaraż/miejsce parkingowe
# 3    balkon\nogródek\ntaras\ngaraż/miejsce parkingo...
# 4                                                 None
# ..                                                 ...
# 387                   balkon\ngaraż/miejsce parkingowe
# 388                                               None
# 389  balkon\ngaraż/miejsce parkingowe\npiwnica\ntyl...
# 390  balkon\ngaraż/miejsce parkingowe\ntylko dla ni...
# 391                                             balkon
#
#                                               location   latitude  longitude  \
# 0    ul. Mariana Hemara, Brzeziny, Białołęka, Warsz...  52.326008  21.043918
# 1     Gumińska 2, Odolany, Wola, Warszawa, mazowieckie  52.220683  20.955828
# 2    ul. Kaliny Jędrusik 9, Sady Żoliborskie, Żolib...  52.256227  20.966515
# 3    ul. Sprzeczna, Stara Praga, Praga-Północ, Wars...  52.248422  21.041618
# 4     Stare Miasto, Śródmieście, Warszawa, mazowieckie   52.24908   21.01475
# ..                                                 ...        ...        ...
# 387  ul. Ogrodowa, Józefosław, Piaseczno, piaseczyń...  52.103019  21.038882
# 388   Józefosław, Piaseczno, piaseczyński, mazowieckie   52.10382   21.03496
# 389   Józefosław, Piaseczno, piaseczyński, mazowieckie   52.10732   21.03996
# 390  al. Wojska Polskiego 10, Piastów, pruszkowski,...  52.187614  20.840414
# 391  ul. Christiana Andersena, Ząbki, wołomiński, m...    52.2832    21.1376
#
#      approximate_coordinates year_of_construction elevator    building_type  \
# 0                      False                 2024      tak  apartamentowiec
# 1                      False                 2021      tak             blok
# 2                      False                 2017      tak  apartamentowiec
# 3                      False                 2018      tak             None
# 4                      False                 1908      nie        kamienica
# ..                       ...                  ...      ...              ...
# 387                    False                 2000      nie             blok
# 388                    False                 2005      nie  apartamentowiec
# 389                    False                 2005      nie             blok
# 390                    False                 2024      tak  apartamentowiec
# 391                    False                 2021      tak             blok
#
#                                   security  \
# 0    teren zamknięty\nmonitoring / ochrona
# 1    teren zamknięty\nmonitoring / ochrona
# 2    teren zamknięty\nmonitoring / ochrona
# 3                          teren zamknięty
# 4                                     None
# ..                                     ...
# 387                        teren zamknięty
# 388                                   None
# 389  teren zamknięty\nmonitoring / ochrona
# 390                                   None
# 391                        teren zamknięty
#
#                                              equipment  \
# 0    zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# 1    zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# 2    zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# 3    zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# 4                                                meble
# ..                                                 ...
# 387        lodówka\nmeble\npiekarnik\nkuchenka\npralka
# 388                                              meble
# 389  zmywarka\nlodówka\nmeble\npiekarnik\ntelewizor...
# 390  zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# 391                             lodówka\nmeble\npralka
#
#                                 utilities  \
# 0                                    None
# 1                                internet
# 2    telewizja kablowa\ninternet\ntelefon
# 3             telewizja kablowa\ninternet
# 4                                    None
# ..                                    ...
# 387                              internet
# 388           telewizja kablowa\ninternet
# 389                                  None
# 390                                  None
# 391                                  None
#
#                                             safeguards  \
# 0      drzwi / okna antywłamaniowe\ndomofon / wideofon
# 1    system alarmowy\ndrzwi / okna antywłamaniowe\n...
# 2      drzwi / okna antywłamaniowe\ndomofon / wideofon
# 3                                   domofon / wideofon
# 4                                                 None
# ..                                                 ...
# 387    drzwi / okna antywłamaniowe\ndomofon / wideofon
# 388                                               None
# 389                                 domofon / wideofon
# 390    drzwi / okna antywłamaniowe\ndomofon / wideofon
# 391                                 domofon / wideofon
#
#                                      announcement_date  \
# 0    (Aktualizacja: 29.12.2024\nDodano: 29.12.2024\...
# 1    (Aktualizacja: 29.12.2024\nDodano: 23.12.2024\...
# 2    (Aktualizacja: 26.12.2024\nDodano: 25.12.2024\...
# 3    (Aktualizacja: 29.12.2024\nDodano: 29.12.2024\...
# 4    (Aktualizacja: 29.12.2024\nDodano: 29.12.2024\...
# ..                                                 ...
# 387  (Aktualizacja: 27.12.2024\nDodano: 27.12.2024\...
# 388  (Aktualizacja: 27.12.2024\nDodano: 27.12.2024\...
# 389  (Aktualizacja: 25.12.2024\nDodano: 25.12.2024\...
# 390  (Aktualizacja: 24.12.2024\nDodano: 24.12.2024\...
# 391  (Aktualizacja: 24.12.2024\nDodano: 23.12.2024\...
#
#                                        adv_description  \
# 0    Wynajmę NOWE, 3 pokojowe umeblowane mieszkanie...
# 1    Do wynajęcia wyjątkowe mieszkanie o powierzchn...
# 2    Wynajmę 3-pokojowe mieszkanie znajdujące się p...
# 3    Klimatyzowane mieszkanie dwupokojowe 52m2 przy...
# 4    3 pokojowy, luksusowy, elegancki apartament o ...
# ..                                                 ...
# 387  Do wynajęcia przytulne mieszkanie 2 pokojowe, ...
# 388  DO WYNAJĘCIA MIESZKANIE 3-POKOJOWE NA KAMERALN...
# 389  Wynajmę bezpośrednio mieszkanie 77,6m2 składaj...
# 390  Do wynajęcia 2-pokojowe, nowe mieszkanie, w pe...
# 391  Do wynajęcia mieszkanie w nowym budownictwie. ...
#
#                                                   link
# 0    https://www.otodom.pl/pl/oferta/nowe-mieszkani...
# 1    https://www.otodom.pl/pl/oferta/wyjatkowe-mies...
# 2    https://www.otodom.pl/pl/oferta/przestronne-3-...
# 3    https://www.otodom.pl/pl/oferta/mieszkanie-52m...
# 4    https://www.otodom.pl/pl/oferta/luksusowy-apar...
# ..                                                 ...
# 387  https://www.otodom.pl/pl/oferta/2-pokoje-na-ka...
# 388  https://www.otodom.pl/pl/oferta/jozefoslaw-3po...
# 389  https://www.otodom.pl/pl/oferta/mieszkanie-77m...
# 390  https://www.otodom.pl/pl/oferta/2-pokojowe-mie...
# 391  https://www.otodom.pl/pl/oferta/kawalerka-w-no...
#
# [392 rows x 24 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df[df.latitude.isna()]
# Out:
# Empty DataFrame
# Columns: [title, rent_price, area_room_num, floor, ogrzewanie, flat_condition, available_from, deposit, advertiser_type, additional_information, location, latitude, longitude, approximate_coordinates, year_of_construction, elevator, building_type, security, equipment, utilities, safeguards, announcement_date, adv_description, link]
# Index: []

# %%
df.iloc[15]
# Out:
# title                      50m2 - Stacja WKD - Nowe osiedle - Wysoki stan...
# rent_price                               4 050 zł\n/miesiąc\n+ Czynsz 850 zł
# area_room_num                          50m²\n3 pokoje\ntylko dla niepalących
# floor                                                               parter/5
# ogrzewanie                                                          miejskie
# flat_condition                                               do zamieszkania
# available_from                                                          None
# deposit                                                             5 000 zł
# advertiser_type                                                     prywatny
# additional_information     ogródek\ngaraż/miejsce parkingowe\ntylko dla n...
# location                         Stare Włochy, Włochy, Warszawa, mazowieckie
# latitude                                                           52.197534
# longitude                                                          20.934822
# approximate_coordinates                                                 True
# year_of_construction                                                    2022
# elevator                                                                 tak
# building_type                                                apartamentowiec
# security                               teren zamknięty\nmonitoring / ochrona
# equipment                  zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# utilities                                                               None
# safeguards                                                domofon / wideofon
# announcement_date          (Aktualizacja: 18.12.2024\nDodano: 14.05.2023\...
# adv_description            Miasteczko Nova Ochota - Łopuszańska 55B - Now...
# link                       https://www.otodom.pl/pl/oferta/50m2-stacja-wk...
# Name: 15, dtype: object

# %%
list(df.iloc[15:17].link)
# Out:
# ['https://www.otodom.pl/pl/oferta/50m2-stacja-wkd-nowe-osiedle-wysoki-standard-ID4lsKE',
#  'https://www.otodom.pl/pl/oferta/mieszkanie-przy-petli-nowodwory-44-7-m2-z-piwnica-ID4tHRF']

# %% [markdown]
# ### RENT PRICE

# %%
df = pd.read_csv('data_raw/otodom_2024_12_21.csv')

# %%
def extract_rent_details(row):
    rent_info = row['rent_price'].replace(',', '.')
    
    rent_price = float(rent_info.split('zł')[0].replace(' ', '').replace('\n', ''))
    
    if '/miesiąc' in rent_info:
        payment_frequency = 'miesiąc'
    else:
        payment_frequency = 'other'
    
    if '+ Czynsz' in rent_info:
        additional_fees_part = rent_info.split('+ Czynsz ')[1]
        additional_fees = float(additional_fees_part.split('zł')[0].replace(' ', '').replace('\n', ''))
    else:
        additional_fees = 0.0
    
    return pd.Series([rent_price, payment_frequency, additional_fees])

df[['rent_price', 'payment_frequency', 'additional_fees']] = df.apply(extract_rent_details, axis=1)

# %% [markdown]
# ### AREA ROOM NUM

# %%
df = pd.read_csv('data_raw/otodom_2024_12_21.csv')

# %%
def extract_flat_details(row):
    flat_info = row['area_room_num']
    
    area = float(flat_info.split('m²')[0].strip())
    
    room_part = [part for part in flat_info.split('\n') if 'pokoi' in part or 'pokoje' in part]
    if room_part:
        rooms = int(room_part[0].split()[0])
    else:
        rooms = 0 
    
    return pd.Series([area, rooms])

df[['area', 'rooms']] = df.apply(extract_flat_details, axis=1)

# %% [markdown]
# ### LAST UPDATE / ADDED

# %%
df = pd.read_csv('data_raw/otodom_2024_12_21.csv')

# %%
df.head(1)
# Out:
#                      title          rent_price  \
# 0  Extra Apartament 120 m2  8 500 zł\n/miesiąc
#
#                            area_room_num     floor ogrzewanie  \
# 0  120m²\n5 pokoi\ntylko dla niepalących  parter/2     gazowe
#
#     flat_condition available_from   deposit advertiser_type  \
# 0  do zamieszkania     2024-12-20  8 500 zł        prywatny
#
#                               additional_information  \
# 0  balkon\nogródek\ngaraż/miejsce parkingowe\ntyl...
#
#                                             location   latitude  longitude  \
# 0  ul. Budki Szczęśliwickie, Stare Włochy, Włochy...  52.207976  20.937515
#
#    approximate_coordinates  year_of_construction elevator     building_type  \
# 0                    False                2020.0      nie  dom wolnostojący
#
#                                 security  \
# 0  teren zamknięty\nmonitoring / ochrona
#
#                                            equipment  \
# 0  zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
#
#                      utilities  \
# 0  telewizja kablowa\ninternet
#
#                                           safeguards  \
# 0  drzwi / okna antywłamaniowe\ndomofon / wideofo...
#
#                                    announcement_date  \
# 0  ('Aktualizacja: 20.12.2024\nDodano: 20.12.2024...
#
#                                      adv_description  \
# 0  Do wynajęcia apartament o luksusowym standardz...
#
#                                                 link
# 0  https://www.otodom.pl/pl/oferta/extra-apartame...

# %%
def extract_ad_dates(row):
    ad_info = row['announcement_date']
    
    update_date_part = [line for line in ad_info.split('\\n') if 'Aktualizacja:' in line]
    last_update = update_date_part[0].replace("('Aktualizacja: ", '').strip() if update_date_part else None
    
    added_date_part = [line for line in ad_info.split('\\n') if 'Dodano:' in line]
    ad_added = added_date_part[0].replace('Dodano: ', '').strip() if added_date_part else None
    
    return pd.Series([last_update, ad_added])

# %%
df[['last_update', 'ad_added']] = df.apply(extract_ad_dates, axis=1)

# %% [markdown]
# ### SEARCH_FOR_INACTIVE

# %%
def search_for_inactive(
    announcements_links : list,
    sleep_length : float = 1,
    return_df : bool = True,
    save_as_csv : bool = True,
    csv_file_name_prefix : str = 'search_for_inactive',
    csv_destination_path : str = 'data_raw') -> pd.DataFrame:
    
    driver = initialize_otodom_scraper(sleep_length)
    
    output = []
    for i in announcements_links:
        driver.get(i)
        sleep(sleep_length)
        
        try:
            expired = driver.find_element(By.XPATH, "//div[@data-cy='expired-ad-alert']")
            output.append([i, 1])
        except NoSuchElementException:
            output.append([i, 0])
            
    df = pd.DataFrame(output, columns=['link', 'expired'])
    current_date = datetime.now().strftime("%Y_%m_%d")
    df['expired_date'] = current_date
        
    # Save as csv
    if save_as_csv:
        file_name = f"{csv_file_name_prefix}_{current_date}.csv"
        path = f'{csv_destination_path}/{file_name}'
        df.to_csv(path,
                  encoding='utf-8',
                  index=False)
        
    return df if return_df else None

# %%
path = f'data_processed/main.csv'
df = pd.read_csv(path)
search_for_inactive(list(df[df.expired.eq(0)].link))

# %% [markdown]
# ### GET NEW ANNOUCMENTS

# %%
def get_links_titles(
    first_page_url : str,
    sleep_length : float = 1,
    return_df : bool = True,
    save_as_csv : bool = True,
    csv_file_name_prefix : str = 'available_ads',
    csv_destination_path : str = 'data_raw') -> pd.DataFrame:
    
    
    driver = initialize_otodom_scraper(sleep_length)
    
    # Container
    announcements = []

    # Loop through otodom using link with prefilled search
    i=1
    while True:
        site = re.sub('&page=[^&]*', f'&page={i}', first_page_url)
        driver.get(site)

        # Iter until page without new result appears
        try:
            driver.find_element(By.XPATH, '//div[@data-cy="no-search-results"]')
            break
        except NoSuchElementException:
            i+=1
        
        # Go to the down of the page to load all announcements
        sleep(sleep_length)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        sleep(sleep_length)
        
        # Get announcements links and titles
        links = driver.find_elements(By.XPATH, '//a[@data-cy="listing-item-link"]')
        titles = driver.find_elements(By.XPATH, '//p[@data-cy="listing-item-title"]')
        
        # Collect data
        for link, title in zip(links, titles):
            announcements.append({
                "link": link.get_attribute('href'),
                "title": title.text.strip()
            })

    # Remove duplicates; return result
    df = pd.DataFrame(announcements).drop_duplicates().reset_index(drop=True)
    current_date = datetime.now().strftime("%Y_%m_%d")
    df['date'] = current_date
    
    # Save as csv
    if save_as_csv:
        file_name = f"{csv_file_name_prefix}_{current_date}.csv"
        path = f'{csv_destination_path}/{file_name}'
        df.to_csv(path,
                  encoding='utf-8',
                  index=False)
        
    return df if return_df else None

# %%
url = 'https://www.otodom.pl/pl/wyniki/wynajem/mieszkanie/mazowieckie/warszawa/warszawa/warszawa?limit=36&daysSinceCreated=7&by=DEFAULT&direction=DESC&viewType=listing&page=2'
get_links_titles(url)
# Out:
#                                                   link  \
# 0    https://www.otodom.pl/pl/oferta/kawalerka-14-p...
# 1    https://www.otodom.pl/pl/oferta/eleganckie-3-p...
# 2    https://www.otodom.pl/pl/oferta/mieszkanie-52m...
# 3    https://www.otodom.pl/pl/oferta/2-pokoje-metro...
# 4    https://www.otodom.pl/pl/oferta/wynajme-mieszk...
# ..                                                 ...
# 456  https://www.otodom.pl/pl/oferta/do-wynajecia-k...
# 457  https://www.otodom.pl/pl/oferta/do-wynajecia-k...
# 458  https://www.otodom.pl/pl/oferta/piaseczno-nowa...
# 459  https://www.otodom.pl/pl/oferta/2-pokoje-na-ka...
# 460  https://www.otodom.pl/pl/oferta/jozefoslaw-3po...
#
#                                                  title        date
# 0    Kawalerka 14.pietro klimatyzacja balkon bezpos...  2025_01_02
# 1              Eleganckie 3-pokoje na Powiślu. English  2025_01_02
# 2       Mieszkanie 52m2 2 Metro Stadion 2 pokoje klima  2025_01_02
# 3                             2 pokoje, Metro Stokłosy  2025_01_02
# 4     Wynajmę mieszkanie 3-pokojowe Warszawa Białołęka  2025_01_02
# ..                                                 ...         ...
# 456  Do wynajęcia kawalerka 24 m2 w pobliżu stacji PKP  2025_01_02
# 457           Do Wynajęcia Kawalerka W Ząbkach K. W-Wy  2025_01_02
# 458  Piaseczno, Nowa Iwiczna - 2 pokoje, garaż, ogr...  2025_01_02
# 459  2 pokoje na kameralnym osiedlu z dużym parkingiem  2025_01_02
# 460  Józefosław 3Pokoje 64 M2 Zamknięte Osiedle Par...  2025_01_02
#
# [461 rows x 3 columns]

# %%
df = pd.read_csv('data_raw/available_ads_2025_01_02.csv')
path = f'data_processed/main.csv'
main = pd.read_csv(path)

# %%
driver = initialize_otodom_scraper(2)
links = list(set(df.link)-set(main.link))

scrape_otodom_announcements(
    driver = driver,
    announcements_links = links,
    sleep_length = 2)
# Out:
#                                                  title  \
# 0       Nowoczesny Apartament przy Elektorowni Powiśle
# 1            Apartament Twarda Cosmopolitan na wynajem
# 2                                        Złota Centrum
# 3    Komfortowe 3 pokoje na Tarchominie, z klimatyz...
# 4           Nowa Kawalerka Przy Stacji Metra Chrzanów!
# ..                                                 ...
# 228   Mieszkanie 57 m2 - Wynajmę, Warszawa-Międzylesie
# 229                 Ul. Nowodworska-3 Pokoje, B. Ładne
# 230                   Apartament na wynajem na Powiślu
# 231                  Apartament W Budynku Cosmopolitan
# 232             Mieszkanie Idealne Dla Studenta, Pary.
#
#                                  rent_price  \
# 0       7 300 zł\n/miesiąc\n+ Czynsz 973 zł
# 1                       12 000 zł\n/miesiąc
# 2       4 000 zł\n/miesiąc\n+ Czynsz 760 zł
# 3       4 000 zł\n/miesiąc\n+ Czynsz 850 zł
# 4       2 000 zł\n/miesiąc\n+ Czynsz 500 zł
# ..                                      ...
# 228     3 000 zł\n/miesiąc\n+ Czynsz 800 zł
# 229     3 500 zł\n/miesiąc\n+ Czynsz 740 zł
# 230  18 000 zł\n/miesiąc\n+ Czynsz 1 000 zł
# 231   11 000 zł\n/miesiąc\n+ Czynsz 0 zł/mc
# 232     2 500 zł\n/miesiąc\n+ Czynsz 430 zł
#
#                              area_room_num floor ogrzewanie   flat_condition  \
# 0                        78.18m²\n2 pokoje   5/6   miejskie  do zamieszkania
# 1                           57m²\n2 pokoje  > 10       None  do zamieszkania
# 2                         51.3m²\n2 pokoje   1/6   miejskie  do zamieszkania
# 3                         50.4m²\n3 pokoje   1/6   miejskie  do zamieszkania
# 4                            12m²\n1 pokój   2/6       None             None
# ..                                     ...   ...        ...              ...
# 228  57m²\n3 pokoje\ntylko dla niepalących   3/4     gazowe  do zamieszkania
# 229                         60m²\n3 pokoje   5/5       None  do zamieszkania
# 230                        120m²\n3 pokoje  None       None             None
# 231                         54m²\n2 pokoje  9/44       None             None
# 232                          31m²\n1 pokój  6/10       None  do zamieszkania
#
#     available_from    deposit      advertiser_type  \
# 0       2025-03-01   7 300 zł  biuro nieruchomości
# 1             None  12 000 zł  biuro nieruchomości
# 2             None   4 000 zł             prywatny
# 3             None   6 000 zł  biuro nieruchomości
# 4       2025-01-02   3 000 zł  biuro nieruchomości
# ..             ...        ...                  ...
# 228           None   4 200 zł             prywatny
# 229     2025-01-01       1 zł  biuro nieruchomości
# 230           None       None  biuro nieruchomości
# 231     2025-01-01          0  biuro nieruchomości
# 232     2025-01-02   2 500 zł  biuro nieruchomości
#
#                                 additional_information  \
# 0                     balkon\ngaraż/miejsce parkingowe
# 1                             garaż/miejsce parkingowe
# 2            balkon\ngaraż/miejsce parkingowe\npiwnica
# 3                             garaż/miejsce parkingowe
# 4                                                 None
# ..                                                 ...
# 228  garaż/miejsce parkingowe\npiwnica\ntylko dla n...
# 229                  garaż/miejsce parkingowe\npiwnica
# 230                                      balkon\ntaras
# 231                                               None
# 232  balkon\ngaraż/miejsce parkingowe\npiwnica\nodd...
#
#                                               location   latitude  longitude  \
# 0    ul. Leszczyńska, Powiśle, Śródmieście, Warszaw...  52.240711  21.025806
# 1       ul. Twarda, Mirów, Wola, Warszawa, mazowieckie  52.231852  20.996083
# 2        ul. Złota, Mirów, Wola, Warszawa, mazowieckie  52.230281  20.998614
# 3           Brzeziny, Białołęka, Warszawa, mazowieckie   52.32022   21.03253
# 4    ul. Szeligowska, Chrzanów, Bemowo, Warszawa, m...   52.22741   20.88849
# ..                                                 ...        ...        ...
# 228  ul. Kożuchowska, Międzylesie, Wawer, Warszawa,...  52.204464  21.172639
# 229  ul. Nowodworska, Nowodwory, Białołęka, Warszaw...   52.32174   20.93916
# 230  ul. Leszczyńska, Powiśle, Śródmieście, Warszaw...  52.240711  21.025806
# 231  ul. Twarda, Śródmieście Północne, Śródmieście,...   52.23539   21.00175
# 232  ul. Korsykańska, Stegny, Mokotów, Warszawa, ma...   52.17575   21.04839
#
#      approximate_coordinates year_of_construction elevator    building_type  \
# 0                      False                 2010      tak             blok
# 1                      False                 None      tak  apartamentowiec
# 2                      False                 1961      tak             blok
# 3                      False                 2009      tak  apartamentowiec
# 4                      False                 2024      tak             None
# ..                       ...                  ...      ...              ...
# 228                    False                 2021      tak  apartamentowiec
# 229                    False                 1999      nie             None
# 230                    False                 None      nie             None
# 231                    False                 2014      nie             None
# 232                    False                 1975      nie             None
#
#                                   security  \
# 0    teren zamknięty\nmonitoring / ochrona
# 1                     monitoring / ochrona
# 2                          teren zamknięty
# 3                     monitoring / ochrona
# 4                                     None
# ..                                     ...
# 228  teren zamknięty\nmonitoring / ochrona
# 229                                   None
# 230                                   None
# 231                                   None
# 232                                   None
#
#                                              equipment  \
# 0    zmywarka\nlodówka\npiekarnik\nkuchenka\ntelewi...
# 1    zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# 2    zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# 3        meble\nlodówka\npiekarnik\nzmywarka\nkuchenka
# 4                                                 None
# ..                                                 ...
# 228  zmywarka\nlodówka\nmeble\npiekarnik\nkuchenka\...
# 229        meble\npiekarnik\nlodówka\npralka\nzmywarka
# 230  zmywarka\nlodówka\nmeble\npiekarnik\ntelewizor...
# 231                                               None
# 232                  meble\npiekarnik\nlodówka\npralka
#
#                                 utilities  \
# 0    telewizja kablowa\ninternet\ntelefon
# 1                                internet
# 2                                internet
# 3                                    None
# 4                                    None
# ..                                    ...
# 228                                  None
# 229                                  None
# 230           telewizja kablowa\ninternet
# 231                                  None
# 232                                  None
#
#                                           safeguards  \
# 0    drzwi / okna antywłamaniowe\ndomofon / wideofon
# 1                system alarmowy\ndomofon / wideofon
# 2          domofon / wideofon\nrolety antywłamaniowe
# 3                                 domofon / wideofon
# 4                                               None
# ..                                               ...
# 228  drzwi / okna antywłamaniowe\ndomofon / wideofon
# 229                                             None
# 230                                             None
# 231                                             None
# 232                                             None
#
#                                      announcement_date  \
# 0    (Aktualizacja: 1.01.2025\nDodano: 1.01.2025\nI...
# 1    (Aktualizacja: 30.12.2024\nDodano: 30.12.2024\...
# 2    (Aktualizacja: 1.01.2025\nDodano: 31.12.2024\n...
# 3    (Aktualizacja: 1.01.2025\nDodano: 30.12.2024\n...
# 4    (Aktualizacja: 1.01.2025\nDodano: 1.01.2025\nI...
# ..                                                 ...
# 228  (Aktualizacja: 1.01.2025\nDodano: 1.01.2025\nI...
# 229  (Aktualizacja: 31.12.2024\nDodano: 27.12.2024\...
# 230  (Aktualizacja: 1.01.2025\nDodano: 31.12.2024\n...
# 231  (Aktualizacja: 29.12.2024\nDodano: 29.12.2024\...
# 232  (Aktualizacja: 31.12.2024\nDodano: 31.12.2024\...
#
#                                        adv_description  \
# 0    Przestronny i Komfortowy Apartament na Wynajem...
# 1    Sunstone Luxury Estate prezentuje ekskluzywny ...
# 2    Wynajmę bezpośrednio dwupokojowe mieszkanie 51...
# 3    Wynajmę piękne, komfortowe 3 pokojowe mieszkan...
# 4    !! NOWA KAWALERKA\n!! ŚWIEŻO WYKOŃCZONA\n!! DO...
# ..                                                 ...
# 228  Do wynajęcia bezpośrednio jasny i nowoczesny a...
# 229  Tylko najem okazjonalny !\n\nBardzo ciche, 3 p...
# 230  Nowoczesny apartament 3-pokojowy na Powiślu – ...
# 231  Oferujemy na wynajem ekskluzywny 2-pokojowy ap...
# 232  Na WYNAJEM kawalerka na warszawskim Mokotowie....
#
#                                                   link
# 0    https://www.otodom.pl/pl/oferta/nowoczesny-apa...
# 1    https://www.otodom.pl/pl/oferta/apartament-twa...
# 2    https://www.otodom.pl/pl/oferta/zlota-centrum-...
# 3    https://www.otodom.pl/pl/oferta/komfortowe-3-p...
# 4    https://www.otodom.pl/pl/oferta/nowa-kawalerka...
# ..                                                 ...
# 228  https://www.otodom.pl/pl/oferta/mieszkanie-57-...
# 229  https://www.otodom.pl/pl/oferta/ul-nowodworska...
# 230  https://www.otodom.pl/pl/oferta/apartament-na-...
# 231  https://www.otodom.pl/pl/oferta/apartament-w-b...
# 232  https://www.otodom.pl/pl/oferta/mieszkanie-ide...
#
# [233 rows x 24 columns]
